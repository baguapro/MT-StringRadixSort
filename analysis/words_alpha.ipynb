# %%
import pandas as pd

# %%
data = pd.read_csv("words_alpha.txt")

# %%
data.columns = ['word']

# %%
data['length'] = data['word'].str.len()

# %%
data['length'].mean()
# Out:
# 9.442547960010808

# %%
data['length'].std()
# Out:
# 2.9163830679059957

# %%
data.length.plot(kind='kde')

# %%
data.hist(column='length')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efdf18560d0>]],
#       dtype=object)
